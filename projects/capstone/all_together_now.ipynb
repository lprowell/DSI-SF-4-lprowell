# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics.pairwise import cosine_distances, cosine_similarity

# %matplotlib inline
# %config InlineBackend.feature_format = 'retina'

# %% [markdown]
# ### Loading in the DataFrame that I made which includes data about all the books. The text of the books has been removed now that I have data about the words, syllables, reading levels, and subjects extracted. I also make the subjects easier to parse through and load up the tfidf vectorized books dataframe and the count vectorized books dataframe.

# %%
meta_stats = pd.read_csv('meta_stats_all_notext', encoding = 'utf8', index_col = 'Unnamed: 0')

# %%
meta_stats['subjects2'] = meta_stats['subjects2'].map(lambda x: x.replace('[', '').replace(']','').split(','))

def clean_sub2(sublist):
    subs = []
    for s in sublist:
        subs.append(s.strip())
    return subs

meta_stats['subjects2'] = meta_stats['subjects2'].map(clean_sub2)

# %%
def unique_words(subjects):
    s = []
    for x in subjects:
        s.extend(x.split(' '))
    return np.unique(s)

meta_stats['subjects3'] = meta_stats['subjects2'].map(unique_words)

# %%
tvec_all = pd.read_csv('tvec_processed/tvec_all', encoding = 'utf8', index_col = 'Unnamed: 0')

# %%
cvec_all = pd.read_csv('processed/cvec_all', encoding = 'utf8', index_col = 'Unnamed: 0')

# %% [markdown]
# ### The user selects a book and the dataframe is narrowed down to only include the books within a range of appropriate reading levels of that book.

# %%
chosen_title = "Peter Pan"

# %%
chosen_book = meta_stats[meta_stats['title'] == chosen_title]
chosen_id = chosen_book['book_id'].values[0]
print chosen_id
chosen_book
# Out:
# 16
#    book_id      title title_ascii                         author  \
# 1       16  Peter Pan    PeterPan  Barrie, J. M. (James Matthew)
#
#    authoryearofbirth  authoryearofdeath  downloads  \
# 1             1860.0             1937.0       4778
#
#                                             subjects  \
# 1  {Peter Pan (Fictitious character) -- Fiction, ...
#
#                                            subjects2       LCC  \
# 1  [fairies, fantasy, fiction, juvenile fiction, ...  {PZ, PR}
#
#                          ...                          sentence_count  \
# 1                        ...                                    3054
#
#    syllable_count  avg_sentence_length  avg_syllables_per_word  dialogue  \
# 1           67117            15.532744                1.414866    1467.0
#
#    dialogue_per_sentence  flesch_reading_ease  flesch_kincaid_grade  \
# 1               0.480354            71.371599              7.163189
#
#                                              formats  \
# 1  {u'text/plain; charset=utf-8': u'http://www.gu...
#
#                                            subjects3
# 1  [character, fairies, fantasy, fiction, fictiti...
#
# [1 rows x 27 columns]

# %% [markdown]
# #### Here is the range of reading levels that will be allowed:

# %%
flesch_k_max = chosen_book['flesch_kincaid_grade'].values[0] + 0.25
flesch_k_min = chosen_book['flesch_kincaid_grade'].values[0] - 1.00
flesch_k_min, flesch_k_max
# Out:
# (6.1631893250800003, 7.4131893250800003)

# %%
flesch_k_subset = meta_stats[meta_stats['flesch_kincaid_grade'].between(flesch_k_min, flesch_k_max)].reset_index(drop = True)
flesch_k_subset.shape
# Out:
# (2930, 27)

# %%
flesch_k_subset.head(2)
# Out:
#    book_id      title title_ascii                         author  \
# 0       15  Moby Dick    MobyDick               Melville, Herman
# 1       16  Peter Pan    PeterPan  Barrie, J. M. (James Matthew)
#
#    authoryearofbirth  authoryearofdeath  downloads  \
# 0             1819.0             1891.0        707
# 1             1860.0             1937.0       4778
#
#                                             subjects  \
# 0  {Ship captains -- Fiction, Whaling ships -- Fi...
# 1  {Peter Pan (Fictitious character) -- Fiction, ...
#
#                                            subjects2       LCC  \
# 0  [adventure stories, ahab, captain fictitious c...      {PS}
# 1  [fairies, fantasy, fiction, juvenile fiction, ...  {PZ, PR}
#
#                          ...                          sentence_count  \
# 0                        ...                                     154
# 1                        ...                                    3054
#
#    syllable_count  avg_sentence_length  avg_syllables_per_word  dialogue  \
# 0            2428             9.889610                1.594222       0.0
# 1           67117            15.532744                1.414866    1467.0
#
#    dialogue_per_sentence  flesch_reading_ease  flesch_kincaid_grade  \
# 0               0.000000            61.925870              7.078767
# 1               0.480354            71.371599              7.163189
#
#                                              formats  \
# 0  {u'text/html': u'http://www.gutenberg.org/eboo...
# 1  {u'text/plain; charset=utf-8': u'http://www.gu...
#
#                                            subjects3
# 0  [adventure, ahab, captain, captains, character...
# 1  [character, fairies, fantasy, fiction, fictiti...
#
# [2 rows x 27 columns]

# %%
subset_bids = flesch_k_subset[['book_id']]
subset_bids.shape
# Out:
# (2930, 1)

# %% [markdown]
# ## Creating a column to recommend books based upon TFIDF
#
# ### Loading in the tfidf vectorized books to use for one metric of recommendation.

# %%
tvec_all.head(5)
# Out:
#     00  000        10        11        12  12mo        13        14        15  \
# 0  0.0  0.0  0.000000  0.000000  0.000000   0.0  0.000000  0.000000  0.000000
# 1  0.0  0.0  0.003734  0.004122  0.004122   0.0  0.004321  0.008664  0.004067
# 2  0.0  0.0  0.000000  0.000000  0.000000   0.0  0.000000  0.000000  0.000000
# 3  0.0  0.0  0.001540  0.000000  0.000000   0.0  0.000000  0.000000  0.000000
# 4  0.0  0.0  0.005085  0.005614  0.005614   0.0  0.000000  0.000000  0.000000
#
#          16 ...   youa  young   younger  youngest  youngster     youth  \
# 0  0.000000 ...    0.0    0.0  0.000000  0.000000        0.0  0.000000
# 1  0.004321 ...    0.0    0.0  0.001161  0.001695        0.0  0.002144
# 2  0.000000 ...    0.0    0.0  0.012668  0.015863        0.0  0.008360
# 3  0.000000 ...    0.0    0.0  0.005742  0.002796        0.0  0.008841
# 4  0.000000 ...    0.0    0.0  0.006321  0.013852        0.0  0.011680
#
#    youthful  youths      zeal  zip
# 0  0.000000     0.0  0.000000  0.0
# 1  0.000000     0.0  0.000000  0.0
# 2  0.000000     0.0  0.005754  0.0
# 3  0.001341     0.0  0.000000  0.0
# 4  0.000000     0.0  0.000000  0.0
#
# [5 rows x 7311 columns]

# %%
tvec_subset = subset_bids.merge(tvec_all, how = 'inner', on = 'book_id').reset_index(drop = True)

# %% [markdown]
# ### I'm using cosine distance to determine how different the books are from each other.

# %%
book_ids = tvec_subset.book_id
tvec_subset = tvec_subset.drop('book_id', axis = 1)

t_subset_distances = cosine_distances(tvec_subset)
t_subset_distances_df = pd.DataFrame(t_subset_distances, columns=book_ids)
t_subset_distances_df['book_id'] = book_ids

t_subset_distances_df.head()
# Out:
# book_id        15        16        24        44        47        51        73  \
# 0        0.000000  0.969081  0.967276  0.954052  0.987929  0.988819  0.974099
# 1        0.969081  0.000000  0.892806  0.830438  0.936222  0.949365  0.942659
# 2        0.967276  0.892806  0.000000  0.632616  0.879938  0.897028  0.864185
# 3        0.954052  0.830438  0.632616  0.000000  0.792673  0.834362  0.827376
# 4        0.987929  0.936222  0.879938  0.792673  0.000000  0.024609  0.941554
#
# book_id        95       111       113   ...        52702     52704     52788  \
# 0        0.976526  0.964068  0.984628   ...     0.976249  0.963928  0.946692
# 1        0.780589  0.913645  0.944498   ...     0.926917  0.940688  0.943436
# 2        0.891896  0.799526  0.886249   ...     0.891607  0.890919  0.888292
# 3        0.849368  0.715684  0.791714   ...     0.707072  0.762762  0.859778
# 4        0.947862  0.902240  0.907432   ...     0.896188  0.935309  0.953450
#
# book_id     52909     52964     53166     53320     53394     53704  book_id
# 0        0.980878  0.989382  0.911926  0.991825  0.939567  0.961188       15
# 1        0.959708  0.968593  0.910546  0.970041  0.941604  0.971819       16
# 2        0.929482  0.932299  0.920757  0.939116  0.890174  0.932117       24
# 3        0.882718  0.867006  0.861252  0.921806  0.858978  0.926615       44
# 4        0.961494  0.939620  0.925159  0.969634  0.957773  0.978592       47
#
# [5 rows x 2931 columns]

# %%
t_chosen_distances = t_subset_distances_df[[chosen_id, 'book_id']]
flesch_k_subset = flesch_k_subset.merge(t_chosen_distances, how = 'inner', on = 'book_id')
flesch_k_subset.rename(columns = {chosen_id : 'tfidf_distances'}, inplace = True)

# %%
flesch_k_subset.sort_values('tfidf_distances').head(5)
# Out:
#       book_id                                              title  \
# 1          16                                          Peter Pan
# 1598    26654                                    Peter and Wendy
# 814     14532  The Honorable Peter Stirling and What People T...
# 218      3074                 The Burgess Bird Book for Children
# 2795    44150                                 The Jack-Knife Man
#
#                                             title_ascii  \
# 1                                              PeterPan
# 1598                                      PeterandWendy
# 814   TheHonorablePeterStirlingandWhatPeopleThoughto...
# 218                       TheBurgessBirdBookforChildren
# 2795                                    TheJackKnifeMan
#
#                                      author  authoryearofbirth  \
# 1             Barrie, J. M. (James Matthew)             1860.0
# 1598          Barrie, J. M. (James Matthew)             1860.0
# 814                    Ford, Paul Leicester             1865.0
# 218   Burgess, Thornton W. (Thornton Waldo)             1874.0
# 2795                   Butler, Ellis Parker             1869.0
#
#       authoryearofdeath  downloads  \
# 1                1937.0       4778
# 1598             1937.0        673
# 814              1902.0          5
# 218              1965.0        217
# 2795             1937.0         11
#
#                                                subjects  \
# 1     {Peter Pan (Fictitious character) -- Fiction, ...
# 1598  {Fantasy, Peter Pan (Fictitious character) -- ...
# 814   {Political fiction, New York (N.Y.) -- Fiction...
# 218                      {Birds -- Juvenile literature}
# 2795  {Widows -- Fiction, River boats -- Fiction, Fa...
#
#                                               subjects2       LCC  \
# 1     [fairies, fantasy, fiction, juvenile fiction, ...  {PZ, PR}
# 1598  [fairies, fantasy, fiction, juvenile fiction, ...  {PR, PZ}
# 814   [fiction, labor movement, love stories, new yo...      {PS}
# 218                        [birds, juvenile literature]      {QL}
# 2795  [fathers and sons, fiction, orphans, river boa...      {PS}
#
#            ...         syllable_count  avg_sentence_length  \
# 1          ...                  67117            15.532744
# 1598       ...                  66921            15.531670
# 814        ...                 223589            13.349320
# 218        ...                 104960            14.092334
# 2795       ...                  68889            15.594901
#
#       avg_syllables_per_word  dialogue  dialogue_per_sentence  \
# 1                   1.414866    1467.0               0.480354
# 1598                1.414073      18.0               0.005907
# 814                 1.468575    5516.5               0.483691
# 218                 1.406348    1624.5               0.306741
# 2795                1.390433    1307.0               0.411394
#
#       flesch_reading_ease  flesch_kincaid_grade  \
# 1               71.371599              7.163189
# 1598            71.439787              7.153412
# 814             69.044036              6.945414
# 218             73.554207              6.500921
# 2795            73.375549              6.899120
#
#                                                 formats  \
# 1     {u'text/plain; charset=utf-8': u'http://www.gu...
# 1598  {u'image/jpeg': u'http://www.gutenberg.org/cac...
# 814   {u'application/rdf+xml': u'http://www.gutenber...
# 218   {u'text/plain; charset=utf-8': u'http://www.gu...
# 2795  {u'image/jpeg': u'http://www.gutenberg.org/cac...
#
#                                               subjects3  tfidf_distances
# 1     [character, fairies, fantasy, fiction, fictiti...         0.000000
# 1598  [character, fairies, fantasy, fiction, fictiti...         0.043960
# 814   [fiction, houses, labor, love, movement, new, ...         0.222722
# 218                       [birds, juvenile, literature]         0.224676
# 2795  [and, boats, customs, fathers, fiction, life, ...         0.243898
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Recommending by Count Vectorized Book Text Similarity

# %%
cvec_subset = subset_bids.merge(cvec_all, how = 'inner', on = 'book_id').reset_index(drop = True)

# %%
book_ids = cvec_subset.book_id
cvec_subset = cvec_subset.drop('book_id', axis = 1)

c_subset_distances = cosine_distances(cvec_subset)
c_subset_distances_df = pd.DataFrame(c_subset_distances, columns=book_ids)
c_subset_distances_df['book_id'] = book_ids

c_subset_distances_df.head()
# Out:
# book_id        15        16        24        44        47        51        73  \
# 0        0.000000  0.990815  0.987949  0.977694  0.996589  0.997602  0.991057
# 1        0.990815  0.000000  0.981642  0.931233  0.977211  0.982835  0.982159
# 2        0.987949  0.981642  0.000000  0.895468  0.985867  0.986507  0.983376
# 3        0.977694  0.931233  0.895468  0.000000  0.972495  0.977811  0.960275
# 4        0.996589  0.977211  0.985867  0.972495  0.000000  0.012037  0.993821
#
# book_id        95       111       113   ...        52702     52704     52788  \
# 0        0.991551  0.994150  0.997887   ...     0.995850  0.996812  0.994831
# 1        0.366504  0.974254  0.981129   ...     0.988063  0.989962  0.980185
# 2        0.990481  0.961743  0.987055   ...     0.992943  0.987791  0.987015
# 3        0.966187  0.894760  0.977674   ...     0.973439  0.925434  0.961747
# 4        0.995072  0.989986  0.991876   ...     0.996701  0.995009  0.996265
#
# book_id     52909     52964     53166     53320     53394     53704  book_id
# 0        0.991668  0.995920  0.890624  0.999528  0.947133  0.996022       15
# 1        0.981780  0.993501  0.854154  0.995692  0.975808  0.996851       16
# 2        0.971960  0.994667  0.989720  0.994957  0.973952  0.962819       24
# 3        0.953189  0.979122  0.970108  0.989110  0.955209  0.990802       44
# 4        0.994297  0.997032  0.985454  0.996490  0.987984  0.996308       47
#
# [5 rows x 2931 columns]

# %%
c_chosen_distances = c_subset_distances_df[[chosen_id, 'book_id']]
flesch_k_subset = flesch_k_subset.merge(c_chosen_distances, how = 'inner', on = 'book_id')
flesch_k_subset.rename(columns = {chosen_id : 'cvec_distances'}, inplace = True)
flesch_k_subset.sort_values('cvec_distances').head(5)
# Out:
#       book_id                    title          title_ascii  \
# 1          16                Peter Pan             PeterPan
# 1598    26654          Peter and Wendy        PeterandWendy
# 7          95    The Prisoner of Zenda   ThePrisonerofZenda
# 2086    32744               The Valley            TheValley
# 2177    34164  A Blot on the Scutcheon  ABlotontheScutcheon
#
#                              author  authoryearofbirth  authoryearofdeath  \
# 1     Barrie, J. M. (James Matthew)             1860.0             1937.0
# 1598  Barrie, J. M. (James Matthew)             1860.0             1937.0
# 7                     Hope, Anthony             1863.0             1933.0
# 2086              Stockham, Richard                NaN                NaN
# 2177        Knowles, Mabel Winifred             1875.0             1949.0
#
#       downloads                                           subjects  \
# 1          4778  {Peter Pan (Fictitious character) -- Fiction, ...
# 1598        673  {Fantasy, Peter Pan (Fictitious character) -- ...
# 7           269  {British -- Foreign countries -- Fiction, Impo...
# 2086          6                   {Science fiction, Short stories}
# 2177          2                                          {Fiction}
#
#                                               subjects2       LCC  \
# 1     [fairies, fantasy, fiction, juvenile fiction, ...  {PZ, PR}
# 1598  [fairies, fantasy, fiction, juvenile fiction, ...  {PR, PZ}
# 7     [adventure stories, british, fiction, foreign ...      {PR}
# 2086                   [science fiction, short stories]      {PS}
# 2177                                          [fiction]      {PR}
#
#            ...        avg_sentence_length  avg_syllables_per_word  dialogue  \
# 1          ...                  15.532744                1.414866    1467.0
# 1598       ...                  15.531670                1.414073      18.0
# 7          ...                  14.990790                1.413390    1522.0
# 2086       ...                  12.575758                1.441997     170.0
# 2177       ...                  13.192982                1.510917    1513.0
#
#       dialogue_per_sentence  flesch_reading_ease  flesch_kincaid_grade  \
# 1                  0.480354            71.371599              7.163189
# 1598               0.005907            71.439787              7.153412
# 7                  0.424784            72.046560              6.934409
# 2086               0.367965            72.077697              6.330105
# 2177               0.308650            65.620576              7.384079
#
#                                                 formats  \
# 1     {u'text/plain; charset=utf-8': u'http://www.gu...
# 1598  {u'image/jpeg': u'http://www.gutenberg.org/cac...
# 7     {u'text/html; charset=utf-8': u'http://www.gut...
# 2086  {u'image/jpeg': u'http://www.gutenberg.org/cac...
# 2177  {u'text/html; charset=iso-8859-1': u'http://ww...
#
#                                               subjects3  tfidf_distances  \
# 1     [character, fairies, fantasy, fiction, fictiti...         0.000000
# 1598  [character, fairies, fantasy, fiction, fictiti...         0.043960
# 7     [adventure, and, british, countries, fiction, ...         0.780589
# 2086                 [fiction, science, short, stories]         0.778836
# 2177                                          [fiction]         0.747298
#
#       cvec_distances
# 1           0.000000
# 1598        0.052676
# 7           0.366504
# 2086        0.413642
# 2177        0.447681
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Recommending Books By Subject Similarity

# %%
def jaccard(list1, list2):
    
    a = set(list1)
    b = set(list2)

    return round(len(a.intersection(b)) / float(len(a.union(b))), 5)

# %%
subject_jaccards = []

for book in range(flesch_k_subset.shape[0]):
    subject_jaccards.append(jaccard(flesch_k_subset.ix[book,'subjects3'].tolist(), 
                                                chosen_book['subjects3'].values[0].tolist()))
    
flesch_k_subset['subject_jaccard'] = subject_jaccards
flesch_k_subset.sort_values('subject_jaccard', ascending = False).head(5)
# Out:
#       book_id                                title  \
# 1598    26654                      Peter and Wendy
# 1          16                            Peter Pan
# 554      9395  Dorothy's Mystical Adventures in Oz
# 597     10419             The Forest Monster of Oz
# 587     10127                       Abducted to Oz
#
#                          title_ascii                         author  \
# 1598                   PeterandWendy  Barrie, J. M. (James Matthew)
# 1                           PeterPan  Barrie, J. M. (James Matthew)
# 554   DorothysMysticalAdventuresinOz               Evans, Robert J.
# 597             TheForestMonsterofOz                Dulabone, Chris
# 587                     AbductedtoOz               Evans, Robert J.
#
#       authoryearofbirth  authoryearofdeath  downloads  \
# 1598             1860.0             1937.0        673
# 1                1860.0             1937.0       4778
# 554                 NaN                NaN         16
# 597                 NaN                NaN          8
# 587                 NaN                NaN         15
#
#                                                subjects  \
# 1598  {Fantasy, Peter Pan (Fictitious character) -- ...
# 1     {Peter Pan (Fictitious character) -- Fiction, ...
# 554   {Oz (Imaginary place) -- Juvenile fiction, Fan...
# 597   {Oz (Imaginary place) -- Juvenile fiction, Fan...
# 587   {Oz (Imaginary place) -- Juvenile fiction, Fan...
#
#                                               subjects2       LCC  \
# 1598  [fairies, fantasy, fiction, juvenile fiction, ...  {PR, PZ}
# 1     [fairies, fantasy, fiction, juvenile fiction, ...  {PZ, PR}
# 554     [fantasy, juvenile fiction, oz imaginary place]      {PZ}
# 597     [fantasy, juvenile fiction, oz imaginary place]      {PZ}
# 587     [fantasy, juvenile fiction, oz imaginary place]      {PZ}
#
#            ...         avg_syllables_per_word  dialogue  \
# 1598       ...                       1.414073      18.0
# 1          ...                       1.414866    1467.0
# 554        ...                       1.512745    1958.5
# 597        ...                       1.468224    1134.5
# 587        ...                       1.484871     652.5
#
#       dialogue_per_sentence  flesch_reading_ease  flesch_kincaid_grade  \
# 1598               0.005907            71.439787              7.153412
# 1                  0.480354            71.371599              7.163189
# 554                0.368347            65.489164              7.396704
# 597                0.381601            70.202874              6.507398
# 587                0.272670            67.884213              7.053626
#
#                                                 formats  \
# 1598  {u'image/jpeg': u'http://www.gutenberg.org/cac...
# 1     {u'text/plain; charset=utf-8': u'http://www.gu...
# 554   {u'image/jpeg': u'http://www.gutenberg.org/cac...
# 597   {u'text/html': u'http://www.gutenberg.org/eboo...
# 587   {u'text/html': u'http://www.gutenberg.org/eboo...
#
#                                               subjects3  tfidf_distances  \
# 1598  [character, fairies, fantasy, fiction, fictiti...         0.043960
# 1     [character, fairies, fantasy, fiction, fictiti...         0.000000
# 554   [fantasy, fiction, imaginary, juvenile, oz, pl...         0.927174
# 597   [fantasy, fiction, imaginary, juvenile, oz, pl...         0.926225
# 587   [fantasy, fiction, imaginary, juvenile, oz, pl...         0.925699
#
#       cvec_distances  subject_jaccard
# 1598        0.052676          1.00000
# 1           0.000000          1.00000
# 554         0.989265          0.35714
# 597         0.982577          0.35714
# 587         0.985527          0.35714
#
# [5 rows x 30 columns]

# %%
s_recs = flesch_k_subset.sort_values('subject_jaccard', ascending = False).head(11).title.values + ' by ' + flesch_k_subset.sort_values('subject_jaccard', ascending = False).head(11).author.values 
t_recs = flesch_k_subset.sort_values('tfidf_distances').head(11).title.values + ' by ' + flesch_k_subset.sort_values('tfidf_distances').head(11).author.values 
c_recs = flesch_k_subset.sort_values('cvec_distances').head(11).title.values + ' by ' + flesch_k_subset.sort_values('cvec_distances').head(11).author.values 

recommended_books = pd.DataFrame({
        'tfidf' : t_recs,
        'subject' : s_recs,
        'cvec' : c_recs
    })

# %%
recommended_books
# Out:
#                                                  cvec  \
# 0          Peter Pan by Barrie, J. M. (James Matthew)
# 1    Peter and Wendy by Barrie, J. M. (James Matthew)
# 2              The Prisoner of Zenda by Hope, Anthony
# 3                     The Valley by Stockham, Richard
# 4   A Blot on the Scutcheon by Knowles, Mabel Wini...
# 5                 The Tree of Heaven by Sinclair, May
# 6              Highland Ballad by Leadem, Christopher
# 7   The City and the World and Other Stories by Ke...
# 8            The White Horses by Sutcliffe, Halliwell
# 9   Barty Crusoe and His Man Saturday by Burnett, ...
# 10           No Defense, Volume 3. by Parker, Gilbert
#
#                                               subject  \
# 0    Peter and Wendy by Barrie, J. M. (James Matthew)
# 1          Peter Pan by Barrie, J. M. (James Matthew)
# 2   Dorothy's Mystical Adventures in Oz by Evans, ...
# 3         The Forest Monster of Oz by Dulabone, Chris
# 4                  Abducted to Oz by Evans, Robert J.
# 5           Pinocchio in Africa by Cherubini, Eugenio
# 6   On the Trail of the Space Pirates by Rockwell,...
# 7   Tom Swift and the Electronic Hydrolung by Appl...
# 8   Tom Swift and His Aerial Warship; Or, The Nava...
# 9   Tom Swift and His Electric Runabout; Or, The S...
# 10  Uncle Wiggily's Adventures by Garis, Howard Roger
#
#                                                 tfidf
# 0          Peter Pan by Barrie, J. M. (James Matthew)
# 1    Peter and Wendy by Barrie, J. M. (James Matthew)
# 2   The Honorable Peter Stirling and What People T...
# 3   The Burgess Bird Book for Children by Burgess,...
# 4          The Jack-Knife Man by Butler, Ellis Parker
# 5                   The Vagrant Duke by Gibbs, George
# 6                Simon Called Peter by Keable, Robert
# 7          The Railway Children by Nesbit, E. (Edith)
# 8   Peter Ruff and the Double Four by Oppenheim, E...
# 9               Red Fleece by Comfort, Will Levington
# 10  Mother West Wind "Where" Stories by Burgess, T...

# %%
fig, ax = plt.subplots(figsize = (12, 12))
subset_similarity = cosine_similarity(tvec_subset)
xlabels = [t + '   ' + str(i) for t, i in zip(flesch_k_subset.title_ascii.head(30).values, flesch_k_subset.book_id.head(30).values)]
ylabels = flesch_k_subset.head(30).book_id.values
sns.heatmap(subset_similarity[:30,:30], xticklabels=xlabels, yticklabels=ylabels)
